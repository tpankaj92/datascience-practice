# %%
print("My data science journey!")
# Out:
# My data science journey!

# %%
# Let's begin

# %%
"""I am focusing now seriously
I will dedictate myself to finish the course and get the job opportunity"""
# Out:
# 'I am focusing now seriously\nI will dedictate myself to finish the course and get the job opportunity'

# %%
a = 10

# %%
a
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
b = "hardwork"
b
# Out:
# 'hardwork'

# %%
type(b)
# Out:
# str

# %%
print(b, a, "success")
# Out:
# hardwork 10 success

# %%
a, b = 29, "my age"

# %%
a, b
# Out:
# (29, 'my age')

# %%
a
# Out:
# 29

# %%
b
# Out:
# 'my age'

# %%
#b = 10

# %%
@b = "djhdj"
# Out:
#   File "C:\Users\tpank\AppData\Local\Temp/ipykernel_10620/1867655077.py", line 1
#     @b = "djhdj"
#        ^
# SyntaxError: invalid syntax

# %%
1g = "cjdb"
# Out:
#   File "C:\Users\tpank\AppData\Local\Temp/ipykernel_10620/3598910356.py", line 1
#     1g = "cjdb"
#      ^
# SyntaxError: invalid syntax

# %%
b% = "kfjkjdfj"
# Out:
#   File "C:\Users\tpank\AppData\Local\Temp/ipykernel_10620/1832227929.py", line 1
#     b% = "kfjkjdfj"
#        ^
# SyntaxError: invalid syntax

# %%
_b = "jewfj"

# %%
_b
# Out:
# 'jewfj'

# %%
name = "pankaj"
userID = "tpankaj"
password = "123@pan"
mail = "tpankajs92@gmail.com"

# %%
a = 1.6

# %%
a
# Out:
# 1.6

# %%
type(a)
# Out:
# float

# %%
h = -5360.235

# %%
h
# Out:
# -5360.235

# %%
type(h)
# Out:
# float

# %%
c = True
d = False

# %%
type(c)
# Out:
# bool

# %%
print(True + True + True + False + True )
# Out:
# 4

# %%
False - True + True
# Out:
# 0

# %%
True * False
# Out:
# 0

# %%
True / False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10620/2917913318.py in <module>
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %%
True % True
# Out:
# 0

# %%
False % False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10620/321047028.py in <module>
# ----> 1 False % False
#
# ZeroDivisionError: integer division or modulo by zero

# %%
p = 45 + 6i
# Out:
#   File "C:\Users\tpank\AppData\Local\Temp/ipykernel_10620/1908411827.py", line 1
#     n = 45 + 6i
#               ^
# SyntaxError: invalid syntax

# %%
n = -12 + 3j
type(n)
# Out:
# complex

# %%
n
# Out:
# (-12+3j)

# %%
q = 5 +8j
r = 3 + 4j

# %%
q*r
# Out:
# (-17+44j)

# %%
1 + "hello"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10620/151453361.py in <module>
# ----> 1 1 + "hello"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
str(2) + "quick"
# Out:
# '2quick'

# %%
"hello" + "hello" + "hello"
# Out:
# 'hellohellohello'

# %%
"hello " * 4
# Out:
# 'hello hello hello hello '

# %%
int("456565")
# Out:
# 456565

# %%
int("hdhsdkjns")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10620/3189154825.py in <module>
# ----> 1 int("hdhsdkjns")
#
# ValueError: invalid literal for int() with base 10: 'hdhsdkjns'

# %%
# we can prompt user to enter the data 
a = input("enter a integer ")
# Out:
# enter a integer sjjd554545

# %%
type(a)
# Out:
# str

# %%
a = int(input("enter integer a: "))
b = int(input("enter integer b: "))
c = int(input("enter integer c: "))
o = (int(a)+int(b))/int(c)
com = 2 + 7j
o1 = o + com
result = str(o1) + "pankaj"
result
# Out:
# enter integer a: 45
# enter integer b: 456
# enter integer c: 56
# '(10.946428571428571+7j)pankaj'

# %%
a, b, c
# Out:
# (5, 54, 56)

# %%
type(c)
# Out:
# str

# %%
o = (int(a)+int(b))/int(c)
o
# Out:
# 1.125

# %%
type(o)
# Out:
# float

# %%
com = 2 + 7j
o1 = o + com

# %%
o1
type(o1)
# Out:
# complex

# %%
result = str(o1) + "pankaj"
result
# Out:
# '(3.125+7j)pankaj'

# %%
"abjjd"  / "sjhsdj"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12220/2538155541.py in <module>
# ----> 1 "abjjd"  / "sjhsdj"
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
